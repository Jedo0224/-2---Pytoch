# %% [markdown]
# # Maximum Likelyhood Estimation

# %% [markdown]
# 우도의 최대화 관점에서 Cost Funtion 정의하기 -> 사전이 일어날 가능도 측정
#
#     y가 일어날 확률, 일어나지 않을 확률를 추정한다 (베르누이 분포)
#
#
#     sigmoid 확률 분포를 따른다.
# ![image.png](attachment:image.png)
#
# 최대가능도방법 (最大可能度方法, 영어: maximum likelihood method) 또는 최대우도법(最大尤度法)은 어떤 확률변수에서 표집한 값들을 토대로 그 확률변수의 모수를 구하는 방법이다. 어떤 모수가 주어졌을 때, '원하는 값들이 나올 가능도를 최대로 만드는' 모수를 선택하는 방법이다. 점추정 방식에 속한다

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # 왜 하는지?

# %% [raw]
# # # Likelihood (가능도) - 압정을 던졌을때 떨어지는 경우 ㅗ(class_1) for ㅜ(class_2) - 예측하여 분포를 확인하고싶다
# # 0과 1의 베르누이 분포를 이용 -> 실제 압정을 던져본다
#
# # class_1을 던졌을 때 obsevation
# # n(던진횟수)= 100
# # k(class_1가 나올 확률) = 27
#
# # y = n!/k!*(n-k)! * theta^k*(1-theta)^n-k
#
# # obsevation을 가장 잘 설명하는(y를 가장 크게 만드는 or minimizer) theta를 찾아내는 과정.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # cross entropy

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
H(P)의 값이 적을 수록 entropy의 값이 적다
